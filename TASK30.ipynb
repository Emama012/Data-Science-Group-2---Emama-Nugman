# %% [markdown]
# # Task 30: Data Preprocessing Using scikit-learn
#
# Preprocessing is a fundamental step in preparing data for machine learning models. It involves transforming raw data into a suitable format for training and evaluation. In this taske will demonstrate how to preprocess data using scikit-learn's powerful tools such as `StandardScaler`, `OneHotEncoder`, and `SimpleImputer`.ill:
# - **Impute Missing Values**: Handle missing data by imputing with appropriate strategies.
# - **Scale Features**: Standardize numerical features to have zero mean and unit variance, improving model performance.
# - **Encode Categorical Variables**: Convert categorical data into numerical format using one-hot enc rformance.

# %%
# Importing librariwss
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# sample dataset
data = {
    'age': [23, 45, 35, 50, 30, None, 40, 33, 29, 60],
    'income': [50000, 100000, 75000, 120000, None, 85000, 95000, 70000, 68000, 110000],
    'gender': ['male', 'female', 'female', 'male', 'female', 'male', 'female', 'male', 'female', 'male'],
    'education': ['bachelor', 'master', 'bachelor', 'doctorate', 'bachelor', 'master', 'master', 'bachelor', 'doctorate', 'bachelor'],
    'target': [0, 1, 0, 1, 0, 1, 1, 0, 1, 1]  
}

#  DataFrame
df = pd.DataFrame(data)

print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#     age    income  gender  education  target
# 0  23.0   50000.0    male   bachelor       0
# 1  45.0  100000.0  female     master       1
# 2  35.0   75000.0  female   bachelor       0
# 3  50.0  120000.0    male  doctorate       1
# 4  30.0       NaN  female   bachelor       0
# 5   NaN   85000.0    male     master       1
# 6  40.0   95000.0  female     master       1
# 7  33.0   70000.0    male   bachelor       0
# 8  29.0   68000.0  female  doctorate       1
# 9  60.0  110000.0    male   bachelor       1

# %%
# features and target
X = df.drop('target', axis=1)
y = df['target']

# numerical and categorical features
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

# Preprocessing pipelines
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # Impute missing values
    ('scaler', StandardScaler())  # Scale features
])

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Impute missing values
    ('onehot', OneHotEncoder(handle_unknown='ignore'))  # Encode categorical variables
])

# Combine preprocessing pipelines
preprocessor = ColumnTransformer([
    ('num', numerical_pipeline, numerical_features),
    ('cat', categorical_pipeline, categorical_features)
])

# full pipeline with a RandomForest model
model_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(random_state=42))  # RandomForest model
])

# %%
# Defining hyperparameters for Grid Search
param_grid = {
    'classifier__n_estimators': [10, 50, 100],
    'classifier__max_depth': [None, 5, 10]
}

# %%
# Applying Grid Search with reduced number of cross-validation splits
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=2, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
