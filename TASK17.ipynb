# %% [markdown]
# ## Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
categories = ['A', 'B', 'C', 'D']
values = [7, 13, 5, 17]
data = np.random.randn(1000)

# Creating a figure with 2x2 subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plotting different types of plots on each subplot
axs[0, 0].plot(x, y1, label='sin(x)', color='blue')
axs[0, 0].set_title('Line Plot')
axs[0, 0].set_xlabel('X-axis')
axs[0, 0].set_ylabel('Y-axis')
axs[0, 0].legend()

axs[0, 1].scatter(x, y2, label='cos(x)', color='red')
axs[0, 1].set_title('Scatter Plot')
axs[0, 1].set_xlabel('X-axis')
axs[0, 1].set_ylabel('Y-axis')
axs[0, 1].legend()

axs[1, 0].bar(categories, values, color='green', edgecolor='black')
axs[1, 0].set_title('Bar Plot')
axs[1, 0].set_xlabel('Categories')
axs[1, 0].set_ylabel('Values')

axs[1, 1].hist(data, bins=30, color='orange', edgecolor='black', alpha=0.7)
axs[1, 1].set_title('Histogram')
axs[1, 1].set_xlabel('Data')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histogram

# %%
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(1, 2, 1000)

plt.figure(figsize=(10, 6))

plt.hist(data1, bins=30, alpha=0.5, label='Data 1', color='blue', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.5, label='Data 2', color='red', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Comparison')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## Box plot

# %%
# Creating box plots for multiple datasets
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.figure(figsize=(10, 6))

plt.boxplot(data, patch_artist=True, showmeans=True)
plt.xticks([1, 2, 3], ['Data 1', 'Data 2', 'Data 3'])
plt.xlabel('Dataset')
plt.ylabel('Value')
plt.title('Box Plot Comparison')

# Customizing box plot colors
colors = ['lightblue', 'lightgreen', 'lightcoral']
for patch, color in zip(plt.boxplot(data)['boxes'], colors):
# Out:
#   Cell In[19], line 15
#
#     ^
# SyntaxError: incomplete input
